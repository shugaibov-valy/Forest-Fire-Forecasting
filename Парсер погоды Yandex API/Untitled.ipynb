# %%
import requests
import bs4
from pprint import pprint

headers = {'X-Yandex-API-Key': 'b80e3cea-7275-4054-95c6-cc8b338ec283'}

link = 'https://api.weather.yandex.ru/v2/forecast?lat=55.75396&lon=37.620393&extra=true'

response = requests.get(link, headers = headers, verify = True)
json_response = response.json()

# температура воздуха
print(json_response['fact']['temp'])

# температура почвы
print(json_response['fact']['soil_temp'])

# влажность почвы
print(json_response['fact']['soil_moisture'])

# относительная влажность
print(json_response['fact']['humidity'])


# атмосферное давление
print(json_response['fact']['pressure_pa'])


# pprint(json_response)
# Out:
# 17
# 17
# 0.28
# 88
# 999

# %%
pprint(json_response)
# Out:
# {'fact': {'accum_prec': {'1': 16.407753, '3': 16.408983, '7': 18.29964},
#           'cloudness': 0.5,
#           'condition': 'cloudy',
#           'daytime': 'd',
#           'feels_like': 18,
#           'humidity': 86,
#           'icon': 'bkn_d',
#           'is_thunder': False,
#           'obs_time': 1622134800,
#           'polar': False,
#           'prec_prob': 0,
#           'prec_strength': 0,
#           'prec_type': 0,
#           'pressure_mm': 750,
#           'pressure_pa': 999,
#           'season': 'spring',
#           'soil_moisture': 0.28,
#           'soil_temp': 20,
#           'source': 'station',
#           'temp': 17,
#           'uptime': 1622137735,
#           'uv_index': 0,
#           'wind_dir': 'se',
#           'wind_gust': 4.6,
#           'wind_speed': 0.9},
#  'forecasts': [{'biomet': {'condition': 'magnetic-field_2', 'index': 2},
#                 'date': '2021-05-27',
#                 'date_ts': 1622062800,
# ...
